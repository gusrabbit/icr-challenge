# %%
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 1000)
import seaborn as sns
sns.set_theme(style="darkgrid")
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.dummy import DummyClassifier
from xgboost import XGBClassifier

# %% [markdown]
# https://www.kaggle.com/competitions/icr-identify-age-related-conditions/data

# %%
train = pd.read_csv('train.csv', index_col=0)
train.shape
# Out:
# (617, 57)

# %%
X = train.drop(columns = ["Class"])
y = train["Class"]

# %% [markdown]
# Vamos seguir o exemplo de código encontrado em https://scikit-learn.org/stable/auto_examples/compose/plot_column_transformer_mixed_types.html.

# %%
numeric_features = X.select_dtypes(include=['float']).columns.to_list()
numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
    ]
)

categorical_features = X.select_dtypes(include=['object']).columns.to_list()
categorical_transformer = Pipeline(
    steps=[
        ("encoder", OneHotEncoder(drop='first')),
    ]
)
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %%
clf = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("dummy", DummyClassifier())
    ]
)

# %%
clf.get_params()

# %%
param_grid = {'dummy__constant' : [0,1],
               'dummy__random_state': [42],
               'dummy__strategy': [
                   "most_frequent",
                   "prior",
                   "stratified",
                   "uniform",
                   "constant"],
              }

# %%
metrics = ['accuracy', 'f1', 'neg_log_loss', 'precision', 'recall', 'roc_auc',]

# %%
grid = GridSearchCV(clf,
                    param_grid=param_grid,
                    scoring=metrics,
                    verbose=1,
                    refit="neg_log_loss",
                    return_train_score=False)

# %%
grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['AB',
#                                                                           'AF',
#                                                                           'AH',
#                                                                           'AM',
#                                                                           'AR',
#                                                                           'AX',
#                                                                           'AY',
#                                                                           'AZ',
#                                                                           'BC',
#                                                                           'BD ',
#                                                                           'BN',
#                                                                           'BP',
#                                                                           'BQ',
#                                                                           'BR',
#                                                                           'BZ',
#                                                                           'CB',
#                                                                           'CC',
#                                                                           'CD ',
#                                                                           'CF',
#                                                                           'CH',
#                                                                           'CL',
#                                                                           'CR',
#                                                                           'CS',
#                                                                           'CU',
#                                                                           'CW ',
#                                                                           'DA',
#                                                                           'DE',
#                                                                           'DF',
#                                                                           'DH',
#                                                                           'DI', ...]),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('encoder',
#                                                                                           OneHotEncoder(drop='first'))]),
#                                                                          ['EJ'])])),
#                                        ('dummy', DummyClassifier())]),
#              param_grid={'dummy__constant': [0, 1], 'dummy__random_state': [42],
#                          'dummy__strategy': ['most_frequent', 'prior',
#                                              'stratified', 'uniform',
#                                              'constant']},
#              refit='neg_log_loss',
#              scoring=['accuracy', 'f1', 'neg_log_loss', 'precision', 'recall',
#                       'roc_auc'],
#              verbose=1)

# %%
pd.DataFrame(grid.cv_results_).sort_values(by='rank_test_neg_log_loss')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1       0.006672      0.000386         0.009393        0.000759
# 6       0.006044      0.000048         0.008783        0.000946
# 3       0.006067      0.000241         0.008563        0.000571
# 8       0.006777      0.000421         0.008434        0.000560
# 0       0.007053      0.000471         0.009986        0.000587
# 4       0.006264      0.000777         0.008563        0.000591
# 5       0.006139      0.000384         0.008647        0.000501
# 2       0.006652      0.000941         0.008936        0.000646
# 7       0.006643      0.000562         0.008473        0.000465
# 9       0.006338      0.000382         0.009041        0.000544
#
#   param_dummy__constant param_dummy__random_state param_dummy__strategy  \
# 1                     0                        42                 prior
# 6                     1                        42                 prior
# 3                     0                        42               uniform
# 8                     1                        42               uniform
# 0                     0                        42         most_frequent
# 4                     0                        42              constant
# 5                     1                        42         most_frequent
# 2                     0                        42            stratified
# 7                     1                        42            stratified
# 9                     1                        42              constant
#
#                                                                                   params  \
# 1          {'dummy__constant': 0, 'dummy__random_state': 42, 'dummy__strategy': 'prior'}
# 6          {'dummy__constant': 1, 'dummy__random_state': 42, 'dummy__strategy': 'prior'}
# 3        {'dummy__constant': 0, 'dummy__random_state': 42, 'dummy__strategy': 'uniform'}
# 8        {'dummy__constant': 1, 'dummy__random_state': 42, 'dummy__strategy': 'uniform'}
# 0  {'dummy__constant': 0, 'dummy__random_state': 42, 'dummy__strategy': 'most_frequent'}
# 4       {'dummy__constant': 0, 'dummy__random_state': 42, 'dummy__strategy': 'constant'}
# 5  {'dummy__constant': 1, 'dummy__random_state': 42, 'dummy__strategy': 'most_frequent'}
# 2     {'dummy__constant': 0, 'dummy__random_state': 42, 'dummy__strategy': 'stratified'}
# 7     {'dummy__constant': 1, 'dummy__random_state': 42, 'dummy__strategy': 'stratified'}
# 9       {'dummy__constant': 1, 'dummy__random_state': 42, 'dummy__strategy': 'constant'}
#
#    split0_test_accuracy  split1_test_accuracy  split2_test_accuracy  \
# 1              0.822581              0.822581              0.821138
# 6              0.822581              0.822581              0.821138
# 3              0.451613              0.435484              0.463415
# 8              0.451613              0.435484              0.463415
# 0              0.822581              0.822581              0.821138
# 4              0.822581              0.822581              0.821138
# 5              0.822581              0.822581              0.821138
# 2              0.709677              0.725806              0.723577
# 7              0.709677              0.725806              0.723577
# 9              0.177419              0.177419              0.178862
#
#    split3_test_accuracy  split4_test_accuracy  mean_test_accuracy  \
# 1              0.829268              0.829268            0.824967
# 6              0.829268              0.829268            0.824967
# 3              0.390244              0.455285            0.439208
# 8              0.390244              0.455285            0.439208
# 0              0.829268              0.829268            0.824967
# 4              0.829268              0.829268            0.824967
# 5              0.829268              0.829268            0.824967
# 2              0.731707              0.699187            0.717991
# 7              0.731707              0.699187            0.717991
# 9              0.170732              0.170732            0.175033
#
#    std_test_accuracy  rank_test_accuracy  split0_test_f1  split1_test_f1  \
# 1           0.003551                   1        0.000000        0.000000
# 6           0.003551                   1        0.000000        0.000000
# 3           0.026114                   8        0.276596        0.255319
# 8           0.026114                   8        0.276596        0.255319
# 0           0.003551                   1        0.000000        0.000000
# 4           0.003551                   1        0.000000        0.000000
# 5           0.003551                   1        0.000000        0.000000
# 2           0.011859                   6        0.142857        0.190476
# 7           0.011859                   6        0.142857        0.190476
# 9           0.003551                  10        0.301370        0.301370
#
#    split2_test_f1  split3_test_f1  split4_test_f1  mean_test_f1  std_test_f1  \
# 1        0.000000        0.000000        0.000000      0.000000     0.000000
# 6        0.000000        0.000000        0.000000      0.000000     0.000000
# 3        0.297872        0.193548        0.279570      0.260581     0.036135
# 8        0.297872        0.193548        0.279570      0.260581     0.036135
# 0        0.000000        0.000000        0.000000      0.000000     0.000000
# 4        0.000000        0.000000        0.000000      0.000000     0.000000
# 5        0.000000        0.000000        0.000000      0.000000     0.000000
# 2        0.190476        0.195122        0.097561      0.163298     0.038024
# 7        0.190476        0.195122        0.097561      0.163298     0.038024
# 9        0.303448        0.291667        0.291667      0.297904     0.005149
#
#    rank_test_f1  split0_test_neg_log_loss  split1_test_neg_log_loss  \
# 1             6                 -0.467488                 -0.467488
# 6             6                 -0.467488                 -0.467488
# 3             2                 -0.693147                 -0.693147
# 8             2                 -0.693147                 -0.693147
# 0             6                 -6.394842                 -6.394842
# 4             6                 -6.394842                 -6.394842
# 5             6                 -6.394842                 -6.394842
# 2             4                -10.464286                 -9.882937
# 7             4                -10.464286                 -9.882937
# 9             1                -29.648812                -29.648812
#
#    split2_test_neg_log_loss  split3_test_neg_log_loss  \
# 1                 -0.469742                 -0.457145
# 6                 -0.469742                 -0.457145
# 3                 -0.693147                 -0.693147
# 8                 -0.693147                 -0.693147
# 0                 -6.446832                 -6.153794
# 4                 -6.446832                 -6.153794
# 5                 -6.446832                 -6.153794
# 2                 -9.963286                 -9.670248
# 7                 -9.963286                 -9.670248
# 9                -29.596821                -29.889859
#
#    split4_test_neg_log_loss  mean_test_neg_log_loss  std_test_neg_log_loss  \
# 1                 -0.457145               -0.463802               0.005497
# 6                 -0.457145               -0.463802               0.005497
# 3                 -0.693147               -0.693147               0.000000
# 8                 -0.693147               -0.693147               0.000000
# 0                 -6.153794               -6.308821               0.127994
# 4                 -6.153794               -6.308821               0.127994
# 5                 -6.153794               -6.308821               0.127994
# 2                -10.842400              -10.164632               0.427427
# 7                -10.842400              -10.164632               0.427427
# 9                -29.889859              -29.734832               0.127994
#
#    rank_test_neg_log_loss  split0_test_precision  split1_test_precision  \
# 1                       1               0.000000               0.000000
# 6                       1               0.000000               0.000000
# 3                       3               0.180556               0.166667
# 8                       3               0.180556               0.166667
# 0                       5               0.000000               0.000000
# 4                       5               0.000000               0.000000
# 5                       5               0.000000               0.000000
# 2                       8               0.150000               0.200000
# 7                       8               0.150000               0.200000
# 9                      10               0.177419               0.177419
#
#    split2_test_precision  split3_test_precision  split4_test_precision  \
# 1               0.000000               0.000000               0.000000
# 6               0.000000               0.000000               0.000000
# 3               0.194444               0.125000               0.180556
# 8               0.194444               0.125000               0.180556
# 0               0.000000               0.000000               0.000000
# 4               0.000000               0.000000               0.000000
# 5               0.000000               0.000000               0.000000
# 2               0.200000               0.200000               0.100000
# 7               0.200000               0.200000               0.100000
# 9               0.178862               0.170732               0.170732
#
#    mean_test_precision  std_test_precision  rank_test_precision  \
# 1             0.000000            0.000000                    6
# 6             0.000000            0.000000                    6
# 3             0.169444            0.023895                    4
# 8             0.169444            0.023895                    4
# 0             0.000000            0.000000                    6
# 4             0.000000            0.000000                    6
# 5             0.000000            0.000000                    6
# 2             0.170000            0.040000                    2
# 7             0.170000            0.040000                    2
# 9             0.175033            0.003551                    1
#
#    split0_test_recall  split1_test_recall  split2_test_recall  \
# 1            0.000000            0.000000            0.000000
# 6            0.000000            0.000000            0.000000
# 3            0.590909            0.545455            0.636364
# 8            0.590909            0.545455            0.636364
# 0            0.000000            0.000000            0.000000
# 4            0.000000            0.000000            0.000000
# 5            0.000000            0.000000            0.000000
# 2            0.136364            0.181818            0.181818
# 7            0.136364            0.181818            0.181818
# 9            1.000000            1.000000            1.000000
#
#    split3_test_recall  split4_test_recall  mean_test_recall  std_test_recall  \
# 1            0.000000            0.000000          0.000000         0.000000
# 6            0.000000            0.000000          0.000000         0.000000
# 3            0.428571            0.619048          0.564069         0.074398
# 8            0.428571            0.619048          0.564069         0.074398
# 0            0.000000            0.000000          0.000000         0.000000
# 4            0.000000            0.000000          0.000000         0.000000
# 5            0.000000            0.000000          0.000000         0.000000
# 2            0.190476            0.095238          0.157143         0.036312
# 7            0.190476            0.095238          0.157143         0.036312
# 9            1.000000            1.000000          1.000000         0.000000
#
#    rank_test_recall  split0_test_roc_auc  split1_test_roc_auc  \
# 1                 6             0.500000             0.500000
# 6                 6             0.500000             0.500000
# 3                 2             0.500000             0.500000
# 8                 2             0.500000             0.500000
# 0                 6             0.500000             0.500000
# 4                 6             0.500000             0.500000
# 5                 6             0.500000             0.500000
# 2                 4             0.484848             0.512478
# 7                 4             0.484848             0.512478
# 9                 1             0.500000             0.500000
#
#    split2_test_roc_auc  split3_test_roc_auc  split4_test_roc_auc  \
# 1             0.500000             0.500000             0.500000
# 6             0.500000             0.500000             0.500000
# 3             0.500000             0.500000             0.500000
# 8             0.500000             0.500000             0.500000
# 0             0.500000             0.500000             0.500000
# 4             0.500000             0.500000             0.500000
# 5             0.500000             0.500000             0.500000
# 2             0.511701             0.516807             0.459384
# 7             0.511701             0.516807             0.459384
# 9             0.500000             0.500000             0.500000
#
#    mean_test_roc_auc  std_test_roc_auc  rank_test_roc_auc
# 1           0.500000          0.000000                  1
# 6           0.500000          0.000000                  1
# 3           0.500000          0.000000                  1
# 8           0.500000          0.000000                  1
# 0           0.500000          0.000000                  1
# 4           0.500000          0.000000                  1
# 5           0.500000          0.000000                  1
# 2           0.497044          0.021957                  9
# 7           0.497044          0.021957                  9
# 9           0.500000          0.000000                  1

# %%
test = pd.read_csv('test.csv', index_col=0)

# %%
test.shape
# Out:
# (5, 56)

# %%
pred = grid.predict(test)

# %%
pred
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)
